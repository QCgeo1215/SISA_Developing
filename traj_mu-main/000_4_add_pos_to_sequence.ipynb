# %%
import pandas as pd
import numpy as np

df_main = pd.read_csv('./taxi_data_Singapore/4-Slidng_Windows_Data_Clustering_Clean-sta-Cluster-Results-20250711.csv')

df_test = df_main[:10]  # 取前10行

print(df_test)
df_test.to_csv('./taxi_data_Singapore/20250725_sample_10_rows.csv', index=False)
# Out:
#           trj_id  kmeans_cluster  week_info  holiday_info  time_period_info  \
# 0  10_1554809147               5          2             1               138
# 1  10_1554809207               5          2             1               138
# 2  10_1554809267               5          2             1               138
# 3  10_1554809327               0          2             1               138
# 4  10_1554809387               0          2             1               138
# 5  10_1554809447               0          2             1               139
# 6  10_1554809507               0          2             1               139
# 7  10_1554809567               0          2             1               139
# 8  10_1554809627               0          2             1               139
# 9  10_1554809687               0          2             1               139
#
#                                             lat_grid  \
# 0  [269, 269, 269, 269, 269, 269, 268, 268, 268, ...
# 1  [265, 265, 265, 265, 266, 266, 266, 267, 267, ...
# 2  [297, 298, 298, 299, 299, 300, 301, 301, 302, ...
# 3  [334, 334, 334, 335, 335, 336, 336, 336, 337, ...
# 4  [344, 344, 344, 344, 345, 345, 345, 345, 345, ...
# 5  [348, 348, 348, 348, 348, 348, 348, 348, 348, ...
# 6  [354, 354, 355, 355, 355, 356, 356, 356, 356, ...
# 7  [367, 367, 368, 368, 368, 368, 368, 368, 368, ...
# 8  [382, 383, 383, 383, 383, 383, 384, 384, 384, ...
# 9  [399, 399, 400, 400, 401, 401, 402, 402, 403, ...
#
#                                             lng_grid final_grid_label  \
# 0  [444, 444, 444, 444, 444, 444, 444, 444, 444, ...       [354, 475]
# 1  [447, 448, 448, 448, 448, 448, 448, 448, 448, ...       [367, 478]
# 2  [452, 452, 452, 452, 452, 452, 452, 453, 453, ...       [382, 479]
# 3  [461, 461, 461, 461, 462, 462, 462, 462, 463, ...       [398, 483]
# 4  [467, 467, 467, 467, 467, 467, 467, 467, 467, ...       [419, 490]
# 5  [470, 470, 470, 470, 470, 470, 470, 471, 471, ...       [442, 500]
# 6  [475, 475, 475, 475, 475, 476, 476, 476, 476, ...       [443, 520]
# 7  [478, 478, 478, 478, 478, 478, 478, 478, 478, ...       [461, 538]
# 8  [479, 479, 479, 479, 479, 479, 479, 479, 479, ...       [475, 537]
# 9  [483, 483, 483, 483, 483, 483, 484, 484, 484, ...       [484, 540]
#
#    lng_grid_0  lat_grid_0  ...  lng_grid_60-sta  lng_grid_90-sta  \
# 0         444         269  ...               -3               -5
# 1         447         265  ...               -5               -8
# 2         452         297  ...               -9              -12
# 3         461         334  ...               -6               -7
# 4         467         344  ...               -3               -5
# 5         470         348  ...               -5               -7
# 6         475         354  ...               -3               -4
# 7         478         367  ...               -1               -1
# 8         479         382  ...               -4               -8
# 9         483         399  ...               -7              -10
#
#    lng_grid_120-sta  lng_grid_150-sta  lng_grid_180-sta  lng_grid_210-sta  \
# 0                -8               -11               -17               -20
# 1               -14               -17               -20               -21
# 2               -15               -16               -18               -20
# 3                -9               -11               -14               -16
# 4                -8               -10               -11               -12
# 5                -8                -9                -9                -9
# 6                -4                -4                -8               -12
# 7                -5                -9               -12               -15
# 8               -11               -14               -21               -31
# 9               -17               -27               -37               -49
#
#    lng_grid_240-sta  lng_grid_270-sta  lng_grid_300-sta  lng_grid_330-sta
# 0               -23               -24               -26               -28
# 1               -23               -25               -28               -30
# 2               -23               -25               -26               -27
# 3               -17               -18               -18               -18
# 4               -12               -12               -16               -20
# 5               -13               -17               -20               -23
# 6               -15               -18               -25               -35
# 7               -22               -32               -42               -54
# 8               -41               -53               -59               -58
# 9               -55               -54               -54               -54
#
# [10 rows x 83 columns]

# %%
import pandas as pd
import ast

# 把字符串形式的列表转为真正的列表（如果尚未转换）
# df_test['lat_grid'] = df_test['lat_grid'].apply(ast.literal_eval)
# df_test['lng_grid'] = df_test['lng_grid'].apply(ast.literal_eval)

# 1. 统计 lat_grid 和 lng_grid 所有值的 max 和 min
lat_all_values = [item for sublist in df_test['lat_grid'] for item in sublist]
lng_all_values = [item for sublist in df_test['lng_grid'] for item in sublist]

lat_min, lat_max = min(lat_all_values), max(lat_all_values)
lng_min, lng_max = min(lng_all_values), max(lng_all_values)

print(f"lat_grid 范围: min = {lat_min}, max = {lat_max}")
print(f"lng_grid 范围: min = {lng_min}, max = {lng_max}")

# 2. 归一化并插入第一位
def normalize_and_insert(grid_list):
    first_val = grid_list[0]
    norm_val = (first_val - 1) / (1001 - 1)
    return [norm_val] + grid_list

df_test['lat_grid_norm'] = df_test['lat_grid'].apply(normalize_and_insert)
df_test['lng_grid_norm'] = df_test['lng_grid'].apply(normalize_and_insert)

# 显示结果
print(df_test[['lat_grid_norm', 'lng_grid_norm']].head())

# 如果需要保存处理后的结果：
# df.to_csv("processed_sample.csv", index=False)
# Out:
# lat_grid 范围: min = 265, max = 478
# lng_grid 范围: min = 444, max = 538
#                                        lat_grid_norm  \
# 0  [0.268, 269, 269, 269, 269, 269, 269, 268, 268...
# 1  [0.264, 265, 265, 265, 265, 266, 266, 266, 267...
# 2  [0.296, 297, 298, 298, 299, 299, 300, 301, 301...
# 3  [0.333, 334, 334, 334, 335, 335, 336, 336, 336...
# 4  [0.343, 344, 344, 344, 344, 345, 345, 345, 345...
#
#                                        lng_grid_norm
# 0  [0.443, 444, 444, 444, 444, 444, 444, 444, 444...
# 1  [0.446, 447, 448, 448, 448, 448, 448, 448, 448...
# 2  [0.451, 452, 452, 452, 452, 452, 452, 452, 453...
# 3  [0.46, 461, 461, 461, 461, 462, 462, 462, 462,...
# 4  [0.466, 467, 467, 467, 467, 467, 467, 467, 467...
# /tmp/ipykernel_1552/359562103.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['lat_grid_norm'] = df_test['lat_grid'].apply(normalize_and_insert)
# /tmp/ipykernel_1552/359562103.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test['lng_grid_norm'] = df_test['lng_grid'].apply(normalize_and_insert)

# %%
import pandas as pd
import numpy as np
import ast

# 读取数据（注意确保 lat_grid 和 lng_grid 是列表格式，如果是字符串形式的列表，要先解析）
df_main = pd.read_csv('./taxi_data_Singapore/4-Slidng_Windows_Data_Clustering_Clean-sta-Cluster-Results-20250711.csv')

# 如果列是字符串形式的列表，需要先转为真正的列表
df_main['lat_grid'] = df_main['lat_grid'].apply(ast.literal_eval)
df_main['lng_grid'] = df_main['lng_grid'].apply(ast.literal_eval)

# 1. 统计 max 和 min
lat_all_values = [item for sublist in df_main['lat_grid'] for item in sublist]
lng_all_values = [item for sublist in df_main['lng_grid'] for item in sublist]

lat_min, lat_max = min(lat_all_values), max(lat_all_values)
lng_min, lng_max = min(lng_all_values), max(lng_all_values)

print(f"lat_grid 范围: min = {lat_min}, max = {lat_max}")
print(f"lng_grid 范围: min = {lng_min}, max = {lng_max}")

# 2. 添加新的字段：归一化首值
def extract_norm_first_val(grid_list):
    return (grid_list[0] - 1) / (1001 - 1)

df_main['lat_grid_first_norm'] = df_main['lat_grid'].apply(extract_norm_first_val)
df_main['lng_grid_first_norm'] = df_main['lng_grid'].apply(extract_norm_first_val)

# 显示前几行看看
print(df_main[['lat_grid_first_norm', 'lng_grid_first_norm']].head(4))

# 保存回原 CSV（推荐备份原始数据）
df_main.to_csv('./taxi_data_Singapore/4-Slidng_Windows_Data_Clustering_Clean-sta-Cluster-Results-20250711_with_norm.csv', index=False)
